# %% [markdown]
# # 파일 - 다운로드(.ipynb 다운로드) 후 본인 작업폴더에 저장하고
# # 파일 이름은 본인이름.ipynb로 수정후 작성하고 제출하세요

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. 202302_202302_주민등록인구및세대현황_월간.csv를 가지고 와서 'data'라는 이름의 데이터 프레임으로 작성하고 5개만 확인합니다.

# %%
import pandas as pd

# %%
data = pd.read_csv('202302_202302_주민등록인구및세대현황_월간.csv',encoding='cp949')

# %%
data.head()
# Out:
#                           행정구역 2023년02월_총인구수 2023년02월_세대수  2023년02월_세대당 인구  \
# 0          서울특별시  (1100000000)     9,427,583    4,457,982             2.11
# 1       서울특별시 종로구 (1111000000)       141,433       72,773             1.94
# 2  서울특별시 종로구 청운효자동(1111051500)        11,605        5,130             2.26
# 3    서울특별시 종로구 사직동(1111053000)         9,120        4,593             1.99
# 4    서울특별시 종로구 삼청동(1111054000)         2,322        1,143             2.03
#
#   2023년02월_남자 인구수 2023년02월_여자 인구수  2023년02월_남여 비율
# 0       4,567,957       4,859,626            0.94
# 1          68,399          73,034            0.94
# 2           5,325           6,280            0.85
# 3           4,060           5,060            0.80
# 4           1,104           1,218            0.91

# %% [markdown]
# ### 2. '행정구역'컬럼을 행정구역명과 행정기관코드로 분리하여 'data' 데이터 프레임에 '행정구역' 컬럼에 행정구역명만 저장하고 5개의 데이터만 확인합니다.

# %%
data['행정구역'] = data['행정구역'].str.split('(').str[0]

# %%
data.head()
# Out:
#               행정구역 2023년02월_총인구수 2023년02월_세대수  2023년02월_세대당 인구  \
# 0          서울특별시       9,427,583    4,457,982             2.11
# 1       서울특별시 종로구        141,433       72,773             1.94
# 2  서울특별시 종로구 청운효자동        11,605        5,130             2.26
# 3    서울특별시 종로구 사직동         9,120        4,593             1.99
# 4    서울특별시 종로구 삼청동         2,322        1,143             2.03
#
#   2023년02월_남자 인구수 2023년02월_여자 인구수  2023년02월_남여 비율
# 0       4,567,957       4,859,626            0.94
# 1          68,399          73,034            0.94
# 2           5,325           6,280            0.85
# 3           4,060           5,060            0.80
# 4           1,104           1,218            0.91

# %% [markdown]
# ### 3. 'data' 데이터 프레임의 컬럼명을 행정구역, 총인구수, 세대수, 세대당인구, 남자, 여자, 남녀비율 로 변경하고 'data'데이터 프레임의 정보를 확인합니다.

# %%
data = data.rename(columns={'2023년02월_총인구수':'총인구수','2023년02월_세대수':'세대수','2023년02월_세대당 인구':'세대당인구','2023년02월_남자 인구수':'남자','2023년02월_여자 인구수':'여자','2023년02월_남여 비율':'남녀비율'})

# %%
data.info
# Out:
# <bound method DataFrame.info of                   행정구역       총인구수        세대수  세대당인구         남자         여자  \
# 0              서울특별시    9,427,583  4,457,982   2.11  4,567,957  4,859,626
# 1           서울특별시 종로구     141,433     72,773   1.94     68,399     73,034
# 2      서울특별시 종로구 청운효자동     11,605      5,130   2.26      5,325      6,280
# 3        서울특별시 종로구 사직동      9,120      4,593   1.99      4,060      5,060
# 4        서울특별시 종로구 삼청동      2,322      1,143   2.03      1,104      1,218
# ...                ...        ...        ...    ...        ...        ...
# 3867  제주특별자치도 서귀포시 서홍동     11,236      4,614   2.44      5,556      5,680
# 3868  제주특별자치도 서귀포시 대륜동     15,567      7,012   2.22      7,837      7,730
# 3869  제주특별자치도 서귀포시 대천동     13,650      6,461   2.11      6,913      6,737
# 3870  제주특별자치도 서귀포시 중문동     12,293      5,995   2.05      6,249      6,044
# 3871  제주특별자치도 서귀포시 예래동      3,880      2,038   1.90      1,994      1,886
#
#       남녀비율
# 0     0.94
# 1     0.94
# 2     0.85
# 3     0.80
# 4     0.91
# ...    ...
# 3867  0.98
# 3868  1.01
# 3869  1.03
# 3870  1.03
# 3871  1.06
#
# [3872 rows x 7 columns]>

# %% [markdown]
# ### 4. 남녀비율 컬럼을 제거하고 'data' 데이터프레임 정보를 확인합니다.

# %%
data = data.drop(columns='남녀비율')

# %%
data.info
# Out:
# <bound method DataFrame.info of                   행정구역       총인구수        세대수  세대당인구         남자         여자
# 0              서울특별시    9,427,583  4,457,982   2.11  4,567,957  4,859,626
# 1           서울특별시 종로구     141,433     72,773   1.94     68,399     73,034
# 2      서울특별시 종로구 청운효자동     11,605      5,130   2.26      5,325      6,280
# 3        서울특별시 종로구 사직동      9,120      4,593   1.99      4,060      5,060
# 4        서울특별시 종로구 삼청동      2,322      1,143   2.03      1,104      1,218
# ...                ...        ...        ...    ...        ...        ...
# 3867  제주특별자치도 서귀포시 서홍동     11,236      4,614   2.44      5,556      5,680
# 3868  제주특별자치도 서귀포시 대륜동     15,567      7,012   2.22      7,837      7,730
# 3869  제주특별자치도 서귀포시 대천동     13,650      6,461   2.11      6,913      6,737
# 3870  제주특별자치도 서귀포시 중문동     12,293      5,995   2.05      6,249      6,044
# 3871  제주특별자치도 서귀포시 예래동      3,880      2,038   1.90      1,994      1,886
#
# [3872 rows x 6 columns]>

# %% [markdown]
# ### 5. 행정구역 컬럼의 ‘(’ ‘)’를 제거하고 시,구,동 컬럼을 만들어 분리해 넣고 세종특별자치시 지역의 값만 선택해서 'sejong' 데이터 프레임에 저장합니다.

# %%
data['시'] = data['행정구역'].str.split(' ').str[0]
data['구'] = data['행정구역'].str.split(' ').str[1]
data['동'] = data['행정구역'].str.split(' ').str[2]
sejong = data[data['시']=='세종특별자치시']

# %%
sejong.head()
# Out:
#                행정구역     총인구수      세대수  세대당인구       남자       여자        시 구  \
# 1253      세종특별자치시    385,285  160,012   2.41  192,110  193,175  세종특별자치시
# 1254      세종특별자치시    385,285  160,012   2.41  192,110  193,175  세종특별자치시
# 1255  세종특별자치시  조치원읍   42,117   20,785   2.03   21,934   20,183  세종특별자치시
# 1256   세종특별자치시  연기면    2,583    1,575   1.64    1,480    1,103  세종특별자치시
# 1257   세종특별자치시  연동면    2,945    1,683   1.75    1,543    1,402  세종특별자치시
#
#          동
# 1253
# 1254
# 1255  조치원읍
# 1256   연기면
# 1257   연동면

# %% [markdown]
# ### 6. 'sejong' 데이터 프레임에 NAN 값이 있다면 해당 행을 제거하고, 기존 인덱스 값은 제거하고 새로 인덱스를 부여하고 내용을 확인합니다.

# %%
sejong = sejong.dropna().reset_index(drop=True)
sejong
# Out:
#              행정구역     총인구수      세대수  세대당인구       남자       여자        시 구     동
# 0       세종특별자치시    385,285  160,012   2.41  192,110  193,175  세종특별자치시
# 1       세종특별자치시    385,285  160,012   2.41  192,110  193,175  세종특별자치시
# 2   세종특별자치시  조치원읍   42,117   20,785   2.03   21,934   20,183  세종특별자치시    조치원읍
# 3    세종특별자치시  연기면    2,583    1,575   1.64    1,480    1,103  세종특별자치시     연기면
# 4    세종특별자치시  연동면    2,945    1,683   1.75    1,543    1,402  세종특별자치시     연동면
# 5    세종특별자치시  부강면    5,834    3,260   1.79    3,228    2,606  세종특별자치시     부강면
# 6    세종특별자치시  금남면    8,601    4,786   1.80    4,607    3,994  세종특별자치시     금남면
# 7    세종특별자치시  장군면    6,901    4,255   1.62    4,046    2,855  세종특별자치시     장군면
# 8    세종특별자치시  연서면    7,177    3,898   1.84    3,948    3,229  세종특별자치시     연서면
# 9    세종특별자치시  전의면    5,472    3,066   1.78    2,912    2,560  세종특별자치시     전의면
# 10   세종특별자치시  전동면    3,245    1,917   1.69    1,742    1,503  세종특별자치시     전동면
# 11   세종특별자치시  소정면    2,204    1,152   1.91    1,177    1,027  세종특별자치시     소정면
# 12   세종특별자치시  한솔동   18,389    6,389   2.88    9,057    9,332  세종특별자치시     한솔동
# 13   세종특별자치시  새롬동   39,847   15,821   2.52   19,391   20,456  세종특별자치시     새롬동
# 14   세종특별자치시  도담동   36,559   15,540   2.35   17,612   18,947  세종특별자치시     도담동
# 15   세종특별자치시  해밀동    8,860    3,129   2.83    4,316    4,544  세종특별자치시     해밀동
# 16   세종특별자치시  아름동   23,521    7,905   2.98   11,620   11,901  세종특별자치시     아름동
# 17   세종특별자치시  종촌동   28,568   10,812   2.64   13,858   14,710  세종특별자치시     종촌동
# 18   세종특별자치시  고운동   35,054   12,318   2.85   17,189   17,865  세종특별자치시     고운동
# 19   세종특별자치시  소담동   21,592    8,290   2.60   10,496   11,096  세종특별자치시     소담동
# 20   세종특별자치시  반곡동   27,056   11,341   2.39   13,366   13,690  세종특별자치시     반곡동
# 21   세종특별자치시  보람동   18,927    6,917   2.74    9,297    9,630  세종특별자치시     보람동
# 22   세종특별자치시  대평동   11,280    4,365   2.58    5,583    5,697  세종특별자치시     대평동
# 23   세종특별자치시  다정동   28,553   10,808   2.64   13,708   14,845  세종특별자치시     다정동

# %% [markdown]
# ### 7. 총인구수, 남자, 여자 컬럼의 데이타 타입을 정수형으로 변경하고 변경내용을 확인합니다.

# %%
sejong['총인구수']=sejong['총인구수'].str.replace(',','').astype(int)
sejong['남자']=sejong['남자'].str.replace(',','').astype(int)
sejong['여자']=sejong['여자'].str.replace(',','').astype(int)

# %%
sejong.head()
# Out:
#             행정구역    총인구수      세대수  세대당인구      남자      여자        시 구     동
# 0      세종특별자치시    385285  160,012   2.41  192110  193175  세종특별자치시
# 1      세종특별자치시    385285  160,012   2.41  192110  193175  세종특별자치시
# 2  세종특별자치시  조치원읍   42117   20,785   2.03   21934   20183  세종특별자치시    조치원읍
# 3   세종특별자치시  연기면    2583    1,575   1.64    1480    1103  세종특별자치시     연기면
# 4   세종특별자치시  연동면    2945    1,683   1.75    1543    1402  세종특별자치시     연동면

# %% [markdown]
# ### 8. 읍면동별로 세종 인구를 차트로 표시합니다.(인구순 5개만)

# %%
sejong.sort_values(by='총인구수',ascending=False)
# Out:
#              행정구역    총인구수      세대수  세대당인구      남자      여자        시 구     동
# 0       세종특별자치시    385285  160,012   2.41  192110  193175  세종특별자치시
# 1       세종특별자치시    385285  160,012   2.41  192110  193175  세종특별자치시
# 2   세종특별자치시  조치원읍   42117   20,785   2.03   21934   20183  세종특별자치시    조치원읍
# 13   세종특별자치시  새롬동   39847   15,821   2.52   19391   20456  세종특별자치시     새롬동
# 14   세종특별자치시  도담동   36559   15,540   2.35   17612   18947  세종특별자치시     도담동
# 18   세종특별자치시  고운동   35054   12,318   2.85   17189   17865  세종특별자치시     고운동
# 17   세종특별자치시  종촌동   28568   10,812   2.64   13858   14710  세종특별자치시     종촌동
# 23   세종특별자치시  다정동   28553   10,808   2.64   13708   14845  세종특별자치시     다정동
# 20   세종특별자치시  반곡동   27056   11,341   2.39   13366   13690  세종특별자치시     반곡동
# 16   세종특별자치시  아름동   23521    7,905   2.98   11620   11901  세종특별자치시     아름동
# 19   세종특별자치시  소담동   21592    8,290   2.60   10496   11096  세종특별자치시     소담동
# 21   세종특별자치시  보람동   18927    6,917   2.74    9297    9630  세종특별자치시     보람동
# 12   세종특별자치시  한솔동   18389    6,389   2.88    9057    9332  세종특별자치시     한솔동
# 22   세종특별자치시  대평동   11280    4,365   2.58    5583    5697  세종특별자치시     대평동
# 15   세종특별자치시  해밀동    8860    3,129   2.83    4316    4544  세종특별자치시     해밀동
# 6    세종특별자치시  금남면    8601    4,786   1.80    4607    3994  세종특별자치시     금남면
# 8    세종특별자치시  연서면    7177    3,898   1.84    3948    3229  세종특별자치시     연서면
# 7    세종특별자치시  장군면    6901    4,255   1.62    4046    2855  세종특별자치시     장군면
# 5    세종특별자치시  부강면    5834    3,260   1.79    3228    2606  세종특별자치시     부강면
# 9    세종특별자치시  전의면    5472    3,066   1.78    2912    2560  세종특별자치시     전의면
# 10   세종특별자치시  전동면    3245    1,917   1.69    1742    1503  세종특별자치시     전동면
# 4    세종특별자치시  연동면    2945    1,683   1.75    1543    1402  세종특별자치시     연동면
# 3    세종특별자치시  연기면    2583    1,575   1.64    1480    1103  세종특별자치시     연기면
# 11   세종특별자치시  소정면    2204    1,152   1.91    1177    1027  세종특별자치시     소정면

# %% [markdown]
# ### 9. Choropleth, geojson 등을 이용하여 세종특별자치시의 동별 인구수를 색상별로 지도에 나타내시오
