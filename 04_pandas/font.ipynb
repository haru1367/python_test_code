# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.randint(-100,100,50).cumsum()  # -100에서 100 사이의 숫자에서 랜덤숫자 50개(누적합 되어 list에 저장)
data
# Out:
# array([ -43,  -65, -106, -182, -244, -158, -243, -307, -310, -384, -328,
#        -327, -301, -244, -272, -180, -233, -243, -249, -176, -226, -257,
#        -357, -266, -175, -272, -301, -299, -376, -467, -530, -462, -450,
#        -406, -406, -354, -424, -396, -426, -508, -421, -393, -311, -279,
#        -216, -304, -396, -383, -299, -231])

# %%
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')
# c:\Users\haru1367\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\haru1367\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\haru1367\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\haru1367\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\haru1367\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
#1.폰트 파일을 FontProperties()생성하고 사용

# %%
import matplotlib.font_manager as fm
path='NanumBarunGothicUltraLight.ttf'
fontprop = fm.FontProperties(fname=path,size=12)
data = np.random.randint(-100,100,50).cumsum() 
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이',fontproperties=fontprop)
plt.ylabel('주식가격',fontproperties=fontprop)
plt.xlabel('시간(분)',fontproperties=fontprop)
# Out:
# Text(0.5, 0, '시간(분)')

# %%
#2 matplotlib.rcParams[]로 설정

# %%
import matplotlib
print('설정파일 위치:',matplotlib.matplotlib_fname())
# Out:
# 설정파일 위치: c:\Users\haru1367\anaconda3\Lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
[(file.name,file.fname) for file in fm.fontManager.ttflist if 'Nanum' in file.name]
# Out:
# [('NanumGothic', 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7fEXTRABOLD.TTF'),
#  ('NanumBarunGothic',
#   'C:\\Users\\haru1367\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothic.ttf'),
#  ('NanumGothic', 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7f.TTF'),
#  ('NanumGothic', 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7fBOLD.TTF'),
#  ('Nanum Pen Script',
#   'C:\\Users\\haru1367\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumPen.ttf'),
#  ('NanumBarunGothic',
#   'C:\\Users\\haru1367\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothicBold.ttf'),
#  ('NanumBarunGothic',
#   'C:\\Users\\haru1367\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothicUltraLight.ttf'),
#  ('NanumBarunGothic',
#   'C:\\Users\\haru1367\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunGothicLight.ttf')]

# %%
plt.rcParams['font.family'] = 'Nanum Pen Script'
plt.rcParams['axes.unicode_minus'] = False

# %%
data = np.random.randint(-100,100,50).cumsum() 
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
#3.설정파일을 직접 수정
print('설정파일 위치:',matplotlib.matplotlib_fname())
# Out:
# 설정파일 위치: c:\Users\haru1367\anaconda3\Lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
import matplotlib.pyplot as plt
print(plt.rcParams['font.family'])
print(plt.rcParams['axes.unicode_minus'])
print(plt.rcParams['font.size'])
plt.rcParams['axes.unicode_minus'] = False
# Out:
# ['Nanum Pen Script']
# False
# 14.0

# %%
import numpy as np
data = np.random.randint(-100,100,50).cumsum() 
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')
